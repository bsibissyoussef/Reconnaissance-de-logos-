# %%
import os
import numpy as np

def print_folders(directory, depth=0):
    if depth == 2:  # stop recursion at depth 2
        return

    for folder in os.listdir(directory):

        folder_path = os.path.join(directory, folder)

        if os.path.isdir(folder_path):

            print(folder_path)
            print_folders(folder_path, depth=depth+1)


dataset_path = r"C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest"

print_folders(dataset_path)
# Out:
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Accessories
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Clothes
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Cosmetic
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Electronic
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Food
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Institution
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Leisure
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Medical
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Necessities
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Transportation
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Cosmetic
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Electronic
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Food
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Institution
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Leisure
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Medical
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Necessities
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation

# %%
import os
import random

base_path = r"C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train"
max_images = 10

for class_name in os.listdir(base_path):
    class_path = os.path.join(base_path, class_name)

    if os.path.isdir(class_path):

        for subfolder in os.listdir(class_path):
            subfolder_path = os.path.join(class_path, subfolder)

            if os.path.isdir(subfolder_path):

                images = os.listdir(subfolder_path)

                if len(images) > max_images:

                    images_to_delete = random.sample(images, len(images) - max_images)

                    for img in images_to_delete:
                        os.remove(os.path.join(subfolder_path, img))

                    print(f"{subfolder_path} réduit à {max_images} images")
# Out:
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\24seven réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Ace réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\aceh réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Admiral réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Aetrex réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Agio réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Aim réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Akubra réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ALAN réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Alexia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Allstar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ara réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Artemide réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Ashbury réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Atlantic réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\AtlanticAirlines réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Audar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Aurora réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Avanti réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Baba réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BACCARAT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BAE réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BakerSkateboards réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Balance réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Bandit réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Barcelo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Basso réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Beeline réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Berghaus réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Berkshire réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Bexley réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BlackandRed réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BlackLabelSkateboards réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Bobdog réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Bona réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Boscovs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BOSS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Boxfresh réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Braun réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Bravo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Breguet réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BridgePort réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Brooke réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Brooklyn réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\BT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Butler réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Buxton réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Cabana réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Calypso réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Carhartt réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Cartier réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\CasaBlanca réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Casino réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Centurion réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\CHRISTOFLE réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Churchs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\CMAirways réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\CMC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Colt réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Consort réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Converse réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Cresta réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Crown réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Crumpler réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Crystal réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Dansko réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\DCShoes réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\diamond réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Dignity réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Domestos réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Domino réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Domus réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\DonJose réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Dor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Drifter réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\DUX réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\DVSShoes réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\DY réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\EagleCreek réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Eastpak réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Ecco réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Elbe réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Emerica réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Emo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Estrella réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Etnies réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Excelsior réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\GeorgiaBoot réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Goya réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Hamilton réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Hammary réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Hanwag réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Healing réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Heritage réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\HMT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Hoffman réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Howard réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Imperia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Jensen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Joy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Keen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Kendo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Klogs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Krystal réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\KYOCERA réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\LaneFurniture réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Leaf réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Lexington réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Libbys réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Lloyd réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\LLoyds réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Longines réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Look réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Loveis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Lowepro réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Makro réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ManhattanPortage réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\MARCBYMARCJACOBS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Margherita réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Matchmakers réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Matt réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\MaverikInc réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\MBT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Meijer réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Meindl réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Memphis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Mendocino réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\miffy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Moca réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Monopoly réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Murray réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\NEI réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Nelson réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Nerds réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Nike réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\NikeSB réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Nippon réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\NordstromRack réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\OMAS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ONE réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ONeill réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Origen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\OsirisShoes réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\PacSun réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Palladium réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Panama réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Papillio réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Patio réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Patron réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\PG réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Phillies réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Pirates réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Premium réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Primo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Proto réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\puma réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Quiksilver réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\RaceWay réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Realtor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\RedDragnfly réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Redline réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Riley réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Rodenstock réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Rogue réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Romika réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Sennheiser réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Seven réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\ShakeJunt réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Sigma réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Skechers réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Smash réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\SpiderMan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\SR réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Steel réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Sterling réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Summit réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Sunlight réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Sunrise réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Supreme réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\swan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\TAGHeuer réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tandy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tango réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tata réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tatiana réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\TeenageMutantNinjaTurtles réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\TheSimpsons réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Thomas réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Thorlos réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\TIGI réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Time réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Titus réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tombstone réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Trebor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Tretorn réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Trio réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Trix réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Unox réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\USTraveler réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Vanessa réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Vargas réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Vasque réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Vault réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\VH réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\VIA réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\WESCO réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Wesson réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Weston réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Xtep réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Accessories\Zamberlan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ABLE réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\AC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ACID réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Acorn réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\AdanyEva réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Addidas réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Advent réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\AFernandez réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ALCO réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Alliance réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\AlmostSkateboards réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Always réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Amador réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Amoco réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Amsterdam réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Anchorage réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\AND1 réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Animal réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ankara réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Annapurna réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Antonius réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Arc réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Arena réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ask réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\BAC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Bahia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Barr réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Basil réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Batman réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Beretta réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\BigLeague réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\BigRed réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Birkis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Birmingham réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\BlackHorse réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Bobdog1 réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Bomber réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Bounce réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Brioni réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Brother réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Browning réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Buddy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Buffalo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Burberry réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Cain réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\California réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Cameo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Carmen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Caro réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\CCM réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ceceba réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Che réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Cheer réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Chicago réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Chicos réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Clement réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ClubSocial réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Columbia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Comfort réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Connaught réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Copelands réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Cosi réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Covert réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Curtis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Danish réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Desigual réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Detroit réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\DIA réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Diana réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dibs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Diesel réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dip réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\DisneyPixar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dixie réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dogwood réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\DolceGabbana réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dome réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Domenico réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Donald réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\DoubleTake réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Dunhill réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\EdHardy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\EKCO réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Element réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ElementSkateboards réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ellesse réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ElPaso réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Elsa réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Emilio réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Era réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Errea réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Escada réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Eskimo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Europa réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Everlast réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Extreme réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Fabrica réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Fox réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Freebirds réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Frigo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Fusion réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Gabriel réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Gap réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\GAS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Gazelle réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Getty réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ghostbusters réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Givova réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Globe réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\GoldRush réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Golite réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Gota réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Grand réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\GStar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\GUnit réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hancock réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hanes réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hartleys réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Haywards réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\HB réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\HearttoHeart réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hield réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hilal réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hilleberg réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Holiday réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\HS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hummel réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hunor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Hurley réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Husky réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ibex réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Ifb réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Imperial réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Indiana réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Intex réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Isla réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\ITS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Jacks réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Jacobs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\JCPenney réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\JMB réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\JOJO réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Kaiser réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Kent réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Kingdom réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\KR3W réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\KSwiss réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Kyoto réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\lacoste réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lane réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LangSha réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lanka réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LaPerla réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lava réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LEA réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LeiteAlves réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lemonade réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lewis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Liberty réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lifeisgood réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Liga réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LimitedEdition réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Linc réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LLC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\logoAndrewChristian réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LordTaylor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\LosAngeles réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lucky réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Luxor réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lynx réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Lyons réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MainStreet réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Maple réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MapleBrown réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Marconi réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Marshmallow réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MDX réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\METROPOLIS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Metropolitan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Miami réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Michigan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Miko réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Minerva réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Mirage réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Miranda réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MitchellsButlers réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Mizuno réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MOL réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Monark réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MONDI réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Montrail réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Moonshine réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Morgan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MountainEquipment réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MP réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\MrT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Msting réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Mumtaz réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Murphy réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\nau réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Nautica réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\NeimanMarcus réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\NEXT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Nickelodeon réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\NineWest réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Nomi réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\NorthCoast réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Nostromo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Nota réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Oceanic réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Oki réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Clothes\Omo réduit à 10 images
# ...
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Freightliner réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Frontier réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Fuji réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Geely réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Genesis réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Gibbs réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\GMC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\GrafStift réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\GreatWall réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\GTBicycles réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\HaiNanAirlines réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\HarleyDavidson réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\HeroCycles réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Hindustan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Holden réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Honda réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Humber réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Husqvarna réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Hyundai réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Infiniti réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Isuzu réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\JAC réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Jaguar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Jeep réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Jets réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\KHS réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Kia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Koenigsegg réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\KogaMiyata réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\KogswellCycles réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Kona réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Koryo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Kross réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Kuota réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Kuwahara réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lada réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lamborghini réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lancia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\landrover réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Landwind réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lapierre réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\LEAR réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lifan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Lincoln réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Litespeed réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\LotusCars réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Magna réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mahindra réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Marussia réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Maserati réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Matchless réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mavic réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mazda réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\McLaren réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\MercedesBenz réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Merlin réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\MG réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Micro réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\MINI réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\MiO réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mitsubishi réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Momentum réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mongoose réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Montague réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Motobecane réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Mustang réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Nascar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Nissan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Norco réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\OKQ8 réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Olmo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Orbea réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Orlando réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Orlen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Overland réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Pagani réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Pemex réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Petrobras réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Petrom réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Petronas réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Peugeot réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Phillips66 réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\PIRELLI réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\PKNOrlen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Polo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Porsche réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Porvenir réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Publix réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Puch réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\RadioFlyer réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Raleigh réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Renault réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Resource réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Rover réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Ruger réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Saga réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\SantaFe réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\SantaMaria réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Schwalbe réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Schwinn réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\ScotRail réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\SCOTT réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Shelby réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Shell réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Signal réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Simson réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\skoda réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Solex réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Specialized réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Spyker réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Ssangyong réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Steyr réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Stinger réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Strada réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\subaru réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\sun réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Taxi réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Tesla réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Total réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Toyota réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Tracker réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\TrekBicycle réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Troller réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Turbo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\TVR réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Tyrell réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Ultramar réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Valero réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Volkswagen réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Volvo réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Vredestein réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Vulcan réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Wheelhouse réduit à 10 images
# C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\train\Transportation\Yamaha réduit à 10 images

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

directory_path = r"C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest"

train_data_path = os.path.join(directory_path, "train")
test_data_path = os.path.join(directory_path, "test")

class_names = os.listdir(train_data_path)

print("Classes:", class_names)
# Out:
# Classes: ['Accessories', 'Clothes', 'Cosmetic', 'Electronic', 'Food', 'Institution', 'Leisure', 'Medical', 'Necessities', 'Transportation']

# %%
# Plot some example color images
fig, axs = plt.subplots(2, 5, figsize=(16, 10))

for i, class_name in enumerate(class_names[:10]):

    class_dir = os.path.join(train_data_path, class_name)
    img_names = []

    for subdir in os.listdir(class_dir):

        subdir_path = os.path.join(class_dir, subdir)

        if os.path.isdir(subdir_path):

            img_names += [
                os.path.join(subdir_path, img_name)
                for img_name in os.listdir(subdir_path)
                if img_name.lower().endswith((".jpg", ".jpeg", ".png")) and not img_name.startswith(".")
            ][:5]

    if len(img_names) < 5:
        continue

    for j, img_path in enumerate(img_names[:5]):

        img = plt.imread(img_path)

        axs[i//5, i%5].imshow(img)
        axs[i//5, i%5].axis('off')

        if j == 0:
            axs[i//5, i%5].set_title(class_name)

plt.suptitle("Example Color Images from Each Class")
plt.subplots_adjust(hspace=0.4)
plt.show()



# Plot some example grayscale images
fig, axs = plt.subplots(2, 5, figsize=(16, 10))

for i, class_name in enumerate(class_names[:10]):

    class_dir = os.path.join(test_data_path, class_name)
    img_names = []

    for subdir in os.listdir(class_dir):

        subdir_path = os.path.join(class_dir, subdir)

        if os.path.isdir(subdir_path):

            img_names += [
                os.path.join(subdir_path, img_name)
                for img_name in os.listdir(subdir_path)
                if img_name.lower().endswith((".jpg", ".jpeg", ".png")) and not img_name.startswith(".")
            ][:5]

    if len(img_names) < 5:
        continue

    for j, img_path in enumerate(img_names[:5]):

        img = plt.imread(img_path)

        img_gray = 0.2989 * img[:,:,0] + 0.5870 * img[:,:,1] + 0.1140 * img[:,:,2]

        axs[i//5, i%5].imshow(img_gray, cmap='gray')
        axs[i//5, i%5].axis('off')

        if j == 0:
            axs[i//5, i%5].set_title(class_name)

plt.suptitle("Example Grayscale Images from Each Class")
plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
import cv2

sift = cv2.SIFT_create()
train_descriptors = []

MAX_PER_CLASS = None

img_paths = []
for class_name in class_names:
    class_imgs = [
        os.path.join(train_data_path, class_name, subdir, img_name)
        for subdir in os.listdir(os.path.join(train_data_path, class_name))
        if os.path.isdir(os.path.join(train_data_path, class_name, subdir))
        for img_name in os.listdir(os.path.join(train_data_path, class_name, subdir))
        if img_name.lower().endswith((".jpg", ".png", ".jpeg"))
    ]
    img_paths += class_imgs[:MAX_PER_CLASS]

print(f"Total images : {len(img_paths)}")

for img_path in img_paths:
    img = cv2.imread(img_path)
    if img is None:
        continue
    img = cv2.resize(img, (64,64))        # 👈 ajouté
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.equalizeHist(gray)            # 👈 ajouté
    _, descriptors = sift.detectAndCompute(gray, None)
    if descriptors is not None:
        train_descriptors.append(descriptors)

train_descriptors = np.vstack(train_descriptors)
print("Nombre total de descripteurs :", train_descriptors.shape)
# Out:
# Total images : 23370

# %%
from sklearn.cluster import MiniBatchKMeans

K = 2000  # Nombre de visual words

print(f"Construction du dictionnaire visuel avec K={K} clusters...")
kmeans = MiniBatchKMeans(n_clusters=K, random_state=42, batch_size=5000, n_init=3)
kmeans.fit(train_descriptors)
print("Dictionnaire visuel construit ✓")
# Out:
# Construction du dictionnaire visuel avec K=2000 clusters...
# Dictionnaire visuel construit ✓

# %%
from sklearn.preprocessing import normalize

def encode_bow(descriptors, kmeans, K):
    histogram = np.zeros(K)
    if descriptors is not None:
        words = kmeans.predict(descriptors)
        for w in words:
            histogram[w] += 1
    return histogram

X_train, y_train = [], []

for img_path in img_paths:
    img = cv2.imread(img_path)
    if img is None:
        continue
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, descriptors = sift.detectAndCompute(gray, None)
    bow_vector = encode_bow(descriptors, kmeans, K)
    X_train.append(bow_vector)
    class_name = os.path.relpath(img_path, train_data_path).split(os.sep)[0]
    y_train.append(class_name)

X_train = normalize(np.array(X_train))
y_train = np.array(y_train)

print(f"X_train shape : {X_train.shape}")
print(f"Nombre de classes : {len(np.unique(y_train))}")
# Out:
# X_train shape : (3000, 2000)
# Nombre de classes : 10

# %%
MAX_PER_CLASS_TEST = Nonw # 20 images de test par classe

test_img_paths = []
for class_name in class_names:
    class_imgs = [
        os.path.join(test_data_path, class_name, subdir, img_name)
        for subdir in os.listdir(os.path.join(test_data_path, class_name))
        if os.path.isdir(os.path.join(test_data_path, class_name, subdir))
        for img_name in os.listdir(os.path.join(test_data_path, class_name, subdir))
        if img_name.lower().endswith((".jpg", ".png", ".jpeg"))
    ]
    test_img_paths += class_imgs[:MAX_PER_CLASS_TEST]

print(f"Total images test : {len(test_img_paths)}")  # doit afficher 200

X_test, y_test = [], []

for img_path in test_img_paths:
    img = cv2.imread(img_path)
    if img is None:
        continue
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, descriptors = sift.detectAndCompute(gray, None)
    bow_vector = encode_bow(descriptors, kmeans, K)
    X_test.append(bow_vector)
    class_name = os.path.relpath(img_path, test_data_path).split(os.sep)[0]
    y_test.append(class_name)

X_test = normalize(np.array(X_test))
y_test = np.array(y_test)

print(f"X_test shape  : {X_test.shape}")
print(f"Nombre de classes : {len(np.unique(y_test))}")  # doit afficher 10
# Out:
# Total images test : 3000
# X_test shape  : (3000, 2000)
# Nombre de classes : 10

# %%
from sklearn.neighbors import KNeighborsClassifier

print("Entraînement du KNN...")
knn = KNeighborsClassifier(n_neighbors=1, metric='cosine', n_jobs=-1)
knn.fit(X_train, y_train)
print("KNN entraîné ✓")
# Out:
# Entraînement du KNN...
# KNN entraîné ✓

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Prédiction
y_pred = knn.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy : {accuracy * 100:.2f}%")

# Rapport détaillé
print("\nClassification Report :")
print(classification_report(y_test, y_pred, target_names=class_names))

# Matrice de confusion
cm = confusion_matrix(y_test, y_pred)
print("Matrice de confusion :")
print(cm)
# Out:
# Accuracy : 39.77%
#
# Classification Report :
#                 precision    recall  f1-score   support
#
#    Accessories       0.41      0.40      0.40       300
#        Clothes       0.36      0.43      0.39       300
#       Cosmetic       0.39      0.41      0.40       300
#     Electronic       0.51      0.42      0.46       300
#           Food       0.47      0.40      0.43       300
#    Institution       0.51      0.39      0.44       300
#        Leisure       0.28      0.31      0.30       300
#        Medical       0.43      0.40      0.41       300
#    Necessities       0.36      0.41      0.39       300
# Transportation       0.35      0.42      0.38       300
#
#       accuracy                           0.40      3000
#      macro avg       0.41      0.40      0.40      3000
#   weighted avg       0.41      0.40      0.40      3000
#
# Matrice de confusion :
# [[119  19  33  12   9  10  21  17  31  29]
#  [ 19 128  18  18   8  14  25  14  28  28]
#  [ 16  30 124   8  14  12  26  19  24  27]
#  [ 22  16  19 125  16   6  26  25  23  22]
#  [ 24  20  20  10 119  16  34  15  15  27]
#  [ 16  26  14  13  21 117  25  23  15  30]
#  [ 27  37  33  14  12  11  94  14  30  28]
#  [ 22  18  17  10  23  19  24 119  31  17]
#  [ 15  36  21  20  14  11  22  18 123  20]
#  [  9  25  22  14  19  14  40  14  18 125]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
classes_presentes = np.unique(y_test) 

# Matrice de confusion
plt.figure(figsize=(12, 8))
sns.heatmap(cm, 
            annot=True, 
            fmt='d', 
            cmap='Blues',
            xticklabels=classes_presentes,
            yticklabels=classes_presentes)
plt.title(f'Matrice de Confusion (Accuracy: {accuracy*100:.2f}%)')
plt.ylabel('Vraie classe')
plt.xlabel('Classe prédite')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# F1-score par classe
from sklearn.metrics import f1_score
f1_scores = f1_score(y_test, y_pred, average=None, labels=classes_presentes)

plt.figure(figsize=(12, 5))
bars = plt.bar(classes_presentes, f1_scores, color=['green' if f > 0.7 else 'orange' if f > 0.5 else 'red' for f in f1_scores])
plt.title('F1-score par classe')
plt.xlabel('Classe')
plt.ylabel('F1-score')
plt.xticks(rotation=45, ha='right')
plt.axhline(y=0.6, color='gray', linestyle='--', label='Seuil 0.6')
plt.legend()
plt.tight_layout()
plt.show()

# %%
def predict_logo(img_path):
    # Charger l'image
    img = cv2.imread(img_path)
    if img is None:
        print("Image introuvable !")
        return
    
    # Extraire SIFT
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, descriptors = sift.detectAndCompute(gray, None)
    
    if descriptors is None:
        print("Aucun descripteur trouvé !")
        return
    
    # Encoder en BoW
    bow_vector = encode_bow(descriptors, kmeans, K)
    bow_vector = normalize(bow_vector.reshape(1, -1))
    
    # Prédiction KNN
    prediction = knn.predict(bow_vector)[0]
    probas = knn.predict_proba(bow_vector)[0]
    confidence = max(probas) * 100
    
    # Affichage
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f'Prédiction : {prediction}\nConfiance : {confidence:.1f}%', fontsize=14)
    plt.tight_layout()
    plt.show()
    
    print(f"Logo détecté : {prediction}")
    print(f"Confiance    : {confidence:.1f}%")

# ─── Tester sur une image ───
img_test_path = r"C:\Users\joz3ph\Documents\ESTSB\python\projet\datasetcopy\trainandtest\test\Food\McDonald's\00001.jpg"
predict_logo(img_test_path)
# Out:
# Image introuvable !

# %%
print("=" * 55)
print("        RÉSUMÉ DU PROJET - RECONNAISSANCE DE LOGOS")
print("=" * 55)

print(f"""
DATASET
   Dataset      : Logo-2K+
   Classes      : {len(classes_presentes)} categories
   Train        : {len(img_paths)} images ({MAX_PER_CLASS} par classe)
   Test         : {len(test_img_paths)} images ({MAX_PER_CLASS_TEST} par classe)

EXTRACTION DE FEATURES
   Methode      : SIFT
   Descripteurs : {train_descriptors.shape[0]} au total
   Taille       : {train_descriptors.shape[1]} dimensions

DICTIONNAIRE VISUEL
   Methode      : MiniBatch K-Means
   Visual Words : K = {K}

CLASSIFICATION
   Modele       : KNN
   K voisins    : {knn.n_neighbors}
   Metrique     : {knn.metric}

RESULTATS
   Accuracy           : {accuracy * 100:.2f}%
   Meilleure classe   : {classes_presentes[np.argmax(f1_scores)]} ({max(f1_scores)*100:.1f}% F1)
   Pire classe        : {classes_presentes[np.argmin(f1_scores)]} ({min(f1_scores)*100:.1f}% F1)
""")

print("=" * 55)
# Out:
# =======================================================
#         RÉSUMÉ DU PROJET - RECONNAISSANCE DE LOGOS
# =======================================================
#
# DATASET
#    Dataset      : Logo-2K+
#    Classes      : 10 categories
#    Train        : 3000 images (300 par classe)
#    Test         : 3000 images (300 par classe)
#
# EXTRACTION DE FEATURES
#    Methode      : SIFT
#    Descripteurs : 134366 au total
#    Taille       : 128 dimensions
#
# DICTIONNAIRE VISUEL
#    Methode      : MiniBatch K-Means
#    Visual Words : K = 2000
#
# CLASSIFICATION
#    Modele       : KNN
#    K voisins    : 1
#    Metrique     : cosine
#
# RESULTATS
#    Accuracy           : 39.77%
#    Meilleure classe   : Electronic (46.0% F1)
#    Pire classe        : Leisure (29.5% F1)
#
# =======================================================

# %%
import pickle
import os

# Crée le dossier models
os.makedirs(r"C:\Users\joz3ph\Documents\ESTSB\python\projet\app\models", exist_ok=True)

# Sauvegarde
pickle.dump(kmeans, open(r"C:\Users\joz3ph\Documents\ESTSB\python\projet\app\models\kmeans.pkl", "wb"))
pickle.dump(knn, open(r"C:\Users\joz3ph\Documents\ESTSB\python\projet\app\models\knn.pkl", "wb"))

print("Modèles KNN sauvegardés ✓")
# Out:
# Modèles KNN sauvegardés ✓
